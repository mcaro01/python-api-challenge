# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
#import stat as st

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 596

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&q=" + cities[i]  
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = city_url
        city_response = requests.get(city_weather, params = {"units": "Imperial"})
        city_json = city_response.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_json["coord"]["lat"]
        city_lng = city_json["coord"]["lon"]
        city_max_temp = city_json["main"]["temp_max"]
        city_humidity =city_json["main"]["humidity"]
        city_clouds = city_json["clouds"]["all"]
        city_wind = city_json["wind"]["speed"]
        city_country = city_json["sys"]["country"]
        city_date = city_json["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | olive branch
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | arraial do cabo
# Processing Record 4 of Set 1 | atuona
# Processing Record 5 of Set 1 | barrow
# Processing Record 6 of Set 1 | henties bay
# Processing Record 7 of Set 1 | port macquarie
# Processing Record 8 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 1 | hami
# Processing Record 10 of Set 1 | port augusta
# Processing Record 11 of Set 1 | canguaretama
# Processing Record 12 of Set 1 | saint george
# Processing Record 13 of Set 1 | pokrovsk
# Processing Record 14 of Set 1 | new norfolk
# Processing Record 15 of Set 1 | bluff
# Processing Record 16 of Set 1 | brae
# Processing Record 17 of Set 1 | bengkulu
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | hamilton
# Processing Record 21 of Set 1 | hithadhoo
# Processing Record 22 of Set 1 | tezu
# Processing Record 23 of Set 1 | burns lake
# Processing Record 24 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 1 | puerto ayora
# Processing Record 26 of Set 1 | qasigiannguit
# Processing Record 27 of Set 1 | guerrero negro
# Processing Record 28 of Set 1 | khani
# Processing Record 29 of Set 1 | mahebourg
# Processing Record 30 of Set 1 | vanimo
# Processing Record 31 of Set 1 | husavik
# Processing Record 32 of Set 1 | sambava
# Processing Record 33 of Set 1 | hobart
# Processing Record 34 of Set 1 | hermanus
# Processing Record 35 of Set 1 | kununurra
# Processing Record 36 of Set 1 | hofn
# Processing Record 37 of Set 1 | dhidhdhoo
# Processing Record 38 of Set 1 | jamestown
# Processing Record 39 of Set 1 | busselton
# Processing Record 40 of Set 1 | kargil
# Processing Record 41 of Set 1 | xichang
# Processing Record 42 of Set 1 | victoria
# Processing Record 43 of Set 1 | kedougou
# Processing Record 44 of Set 1 | nhulunbuy
# Processing Record 45 of Set 1 | hilo
# Processing Record 46 of Set 1 | ponta do sol
# Processing Record 47 of Set 1 | sergeyevka
# Processing Record 48 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 49 of Set 1 | kavieng
# Processing Record 50 of Set 1 | pizarro
# Processing Record 0 of Set 2 | ushuaia
# Processing Record 1 of Set 2 | tsienyane
# City not found. Skipping...
# Processing Record 2 of Set 2 | buala
# Processing Record 3 of Set 2 | vaini
# Processing Record 4 of Set 2 | dikson
# Processing Record 5 of Set 2 | seoul
# Processing Record 6 of Set 2 | kelheim
# Processing Record 7 of Set 2 | carnarvon
# Processing Record 8 of Set 2 | faanui
# Processing Record 9 of Set 2 | nabire
# Processing Record 10 of Set 2 | pangnirtung
# Processing Record 11 of Set 2 | richards bay
# Processing Record 12 of Set 2 | tiksi
# Processing Record 13 of Set 2 | chapais
# Processing Record 14 of Set 2 | clyde river
# Processing Record 15 of Set 2 | kaitangata
# Processing Record 16 of Set 2 | machachi
# Processing Record 17 of Set 2 | kapaa
# Processing Record 18 of Set 2 | okato
# Processing Record 19 of Set 2 | asau
# Processing Record 20 of Set 2 | moron
# Processing Record 21 of Set 2 | ribeira grande
# Processing Record 22 of Set 2 | salym
# Processing Record 23 of Set 2 | saint-philippe
# Processing Record 24 of Set 2 | provideniya
# Processing Record 25 of Set 2 | ancud
# Processing Record 26 of Set 2 | falkoping
# City not found. Skipping...
# Processing Record 27 of Set 2 | lavrentiya
# Processing Record 28 of Set 2 | port elizabeth
# Processing Record 29 of Set 2 | yellowknife
# Processing Record 30 of Set 2 | fevralsk
# City not found. Skipping...
# Processing Record 31 of Set 2 | qaanaaq
of Set 4 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 4 | ambovombe
# Processing Record 19 of Set 4 | padang
# Processing Record 20 of Set 4 | kebemer
# City not found. Skipping...
# Processing Record 21 of Set 4 | lubango
# Processing Record 22 of Set 4 | pedra
# Processing Record 23 of Set 4 | hambantota
# Processing Record 24 of Set 4 | sorong
# Processing Record 25 of Set 4 | fare
# Processing Record 26 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 4 | bethel
# Processing Record 28 of Set 4 | nikolskoye
# Processing Record 29 of Set 4 | berbera
# Processing Record 30 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 4 | butaritari
# Processing Record 32 of Set 4 | lagoa
# Processing Record 33 of Set 4 | norman wells
# Processing Record 34 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 4 | sao filipe
# Processing Record 36 of Set 4 | aswan
# Processing Record 37 of Set 4 | hoquiam
# Processing Record 38 of Set 4 | sibolga
# Processing Record 39 of Set 4 | tottori
# Processing Record 40 of Set 4 | aldan
# Processing Record 41 of Set 4 | nador
# Processing Record 42 of Set 4 | beloha
# Processing Record 43 of Set 4 | ucluelet
# Processing Record 44 of Set 4 | warrnambool
# Processing Record 45 of Set 4 | chuy
# Processing Record 46 of Set 4 | tondon
# Processing Record 47 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 4 | havre-saint-pierre
# Processing Record 49 of Set 4 | talaya
# Processing Record 0 of Set 5 | vila velha
# Processing Record 1 of Set 5 | isangel
# Processing Record 2 of Set 5 | luancheng
# Processing Record 3 of Set 5 | saskylakh
# Processing Record 4 of Set 5 | chokurdakh
# Processing Record 5 of Set 5 | tuktoyaktuk
# Processing Record 6 of Set 5 | marienburg
# Processing Record 7 of Set 5 | hobyo
# Processing Record 8 of Set 5 | san cristobal
# Processing Record 9 of Set 5 | arawa
# Processing Record 10 of Set 5 | chicama
# Processing Record 11 of Set 5 | vao
# Processing Record 12 of Set 5 | grand gaube
# Processing Record 13 of Set 5 | sitka
# Processing Record 14 of Set 5 | son la
# Processing Record 15 of Set 5 | hue
# Processing Record 16 of Set 5 | tucurui
# Processing Record 17 of Set 5 | akdepe
# Processing Record 18 of Set 5 | kuytun
# Processing Record 19 of Set 5 | maragogi
# Processing Record 20 of Set 5 | benjamin aceval
# Processing Record 21 of Set 5 | umm kaddadah
# Processing Record 22 of Set 5 | santa rosa
# Processing Record 23 of Set 5 | kodiak
# Processing Record 24 of Set 5 | college
# Processing Record 25 of Set 5 | aklavik
# Processing Record 26 of Set 5 | kaili
# Processing Record 27 of Set 5 | naze
# Processing Record 28 of Set 5 | takoradi
# Processing Record 29 of Set 5 | winnemucca
# Processing Record 30 of Set 5 | ilulissat
# Processing Record 31 of Set 5 | khatanga
# Processing Record 32 of Set 5 | krasnoselkup
# Processing Record 33 of Set 5 | narsaq
# Processing Record 34 of Set 5 | mizdah
# Processing Record 35 of Set 5 | nelson bay
# Processing Record 36 of Set 5 | da lat
# Processing Record 37 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 5 | talcahuano
# Processing Record 39 of Set 5 | chornukhy
# Processing Record 40 of Set 5 | bereda
# Processing Record 41 of Set 5 | yar-sale
# Processing Record 42 of Set 5 | klaksvik
# Processing Record 43 of Set 5 | woodward
# Processing Record 44 of Set 5 | goderich
# Processing Record 45 of Set 5 | dijkot
# Processing Record 46 of Set 5 | hasaki
# Processing Record 47 of Set 5 | puerto escondido
# Processing Record 48 of Set 5 | sovetskiy
# Processing Record 49 of Set 5 | marawi
# Processing Record 0 of Set 6 | pecos
# Processing Record 1 of Set 6 | roald
# Processing Record 2 of Set 6 | trinidad
# Processing Record 3 of Set 6 | cloquet
# Processing Record 4 of Set 6 | thompson
# Processing Record 5 of Set 6 | laguna
# Processing Record 6 of Set 6 | talara
# Processing Record 7 of Set 6 | rochegda
# Processing Record 8 of Set 6 | oktyabrskiy
# Processing Record 9 of Set 6 | nanortalik
# Processing Record 10 of Set 6 | deputatskiy
# Processing Record 11 of Set 6 | umm ruwabah
# City not found. Skipping...
# Processing Record 12 of Set 6 | palatka
# Processing Record 13 of Set 6 | abu samrah
# Processing Record 14 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 6 | palmerston
# Processing Record 16 of Set 6 | cairns
# Processing Record 17 of Set 6 | leningradskiy
# Processing Record 18 of Set 6 | avera
# Processing Record 19 of Set 6 | gwanda
# Processing Record 20 of Set 6 | raudeberg
# Processing Record 21 of Set 6 | dali
# Processing Record 22 of Set 6 | sao jose da coroa grande
# Processing Record 23 of Set 6 | san jeronimito
# Processing Record 24 of Set 6 | nortelandia
# Processing Record 25 of Set 6 | the pas
# Processing Record 26 of Set 6 | thinadhoo
# Processing Record 27 of Set 6 | senneterre
# Processing Record 28 of Set 6 | ostrovnoy
# Processing Record 29 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 30 of Set 6 | batagay
# Processing Record 31 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 6 | mayumba
# Processing Record 33 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 34 of Set 6 | nykobing
# City not found. Skipping...
# Processing Record 35 of Set 6 | lorengau
# Processing Record 36 of Set 6 | kokkola
# Processing Record 37 of Set 6 | tabou
# Processing Record 38 of Set 6 | aksarayskiy
# Processing Record 39 of Set 6 | umm lajj
# Processing Record 40 of Set 6 | tarakan
# Processing Record 41 of Set 6 | finschhafen
# Processing Record 42 of Set 6 | palauig
# Processing Record 43 of Set 6 | cabatuan
# Processing Record 44 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 6 | bathsheba
# Processing Record 46 of Set 6 | harlingen
# Processing Record 47 of Set 6 | matara
# Processing Record 48 of Set 6 | senekal
# Processing Record 49 of Set 6 | andijon
# Processing Record 0 of Set 7 | saint-augustin
# Processing Record 1 of Set 7 | nyurba
# Processing Record 2 of Set 7 | kramat
# Processing Record 3 of Set 7 | hohhot
# Processing Record 4 of Set 7 | perth
# Processing Record 5 of Set 7 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 7 | gizo
# Processing Record 7 of Set 7 | north platte
# Processing Record 8 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 7 | valera
# Processing Record 10 of Set 7 | bima
# Processing Record 11 of Set 7 | mount gambier
# Processing Record 12 of Set 7 | xinxiang
# Processing Record 13 of Set 7 | roebourne
# Processing Record 14 of Set 7 | ola
# Processing Record 15 of Set 7 | fenoarivo
# Processing Record 16 of Set 7 | luderitz
# Processing Record 17 of Set 7 | tommot
# Processing Record 18 of Set 7 | luanda
# Processing Record 19 of Set 7 | nynashamn
# Processing Record 20 of Set 7 | longlac
# City not found. Skipping...
# Processing Record
# Processing Record 39 of Set 8 | ferrol
# Processing Record 40 of Set 8 | cidreira
# Processing Record 41 of Set 8 | moyale
# Processing Record 42 of Set 8 | walla walla
# Processing Record 43 of Set 8 | kapit
# Processing Record 44 of Set 8 | pangkalanbuun
# Processing Record 45 of Set 8 | banda aceh
# Processing Record 46 of Set 8 | north bend
# Processing Record 47 of Set 8 | sept-iles
# Processing Record 48 of Set 8 | peterhead
# Processing Record 49 of Set 8 | dudinka
# Processing Record 0 of Set 9 | deer lake
# Processing Record 1 of Set 9 | aroeiras
# Processing Record 2 of Set 9 | valparaiso
# Processing Record 3 of Set 9 | mildura
# Processing Record 4 of Set 9 | padre paraiso
# Processing Record 5 of Set 9 | filadelfia
# Processing Record 6 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 7 of Set 9 | naron
# Processing Record 8 of Set 9 | columbus
# Processing Record 9 of Set 9 | anadyr
# Processing Record 10 of Set 9 | fort nelson
# Processing Record 11 of Set 9 | whitehorse
# Processing Record 12 of Set 9 | itoman
# Processing Record 13 of Set 9 | njeru
# Processing Record 14 of Set 9 | atambua
# Processing Record 15 of Set 9 | wulanhaote
# City not found. Skipping...
# Processing Record 16 of Set 9 | aberdeen
# Processing Record 17 of Set 9 | kutum
# Processing Record 18 of Set 9 | kerepehi
# Processing Record 19 of Set 9 | luang prabang
# Processing Record 20 of Set 9 | praia
# Processing Record 21 of Set 9 | morros
# Processing Record 22 of Set 9 | kaseda
# Processing Record 23 of Set 9 | tuatapere
# Processing Record 24 of Set 9 | altamont
# Processing Record 25 of Set 9 | buin
# Processing Record 26 of Set 9 | pattan
# Processing Record 27 of Set 9 | sapa
# Processing Record 28 of Set 9 | sortland
# Processing Record 29 of Set 9 | mnogovershinnyy
# Processing Record 30 of Set 9 | cururupu
# Processing Record 31 of Set 9 | vila franca do campo
# Processing Record 32 of Set 9 | te anau
# Processing Record 33 of Set 9 | birobidzhan
# Processing Record 34 of Set 9 | noyabrsk
# Processing Record 35 of Set 9 | beringovskiy
# Processing Record 36 of Set 9 | garowe
# Processing Record 37 of Set 9 | picton
# Processing Record 38 of Set 9 | nemuro
# Processing Record 39 of Set 9 | vilani
# Processing Record 40 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 41 of Set 9 | fairbanks
# Processing Record 42 of Set 9 | komsomolskiy
# Processing Record 43 of Set 9 | linjiang
# Processing Record 44 of Set 9 | gashua
# Processing Record 45 of Set 9 | tual
# Processing Record 46 of Set 9 | kalmunai
# Processing Record 47 of Set 9 | wuwei
# Processing Record 48 of Set 9 | tunceli
# Processing Record 49 of Set 9 | ketchikan
# Processing Record 0 of Set 10 | mount isa
# Processing Record 1 of Set 10 | jujuy
# City not found. Skipping...
# Processing Record 2 of Set 10 | tamandare
# Processing Record 3 of Set 10 | sinnamary
# Processing Record 4 of Set 10 | isla vista
# Processing Record 5 of Set 10 | morgan city
# Processing Record 6 of Set 10 | dukat
# Processing Record 7 of Set 10 | ugoofaaru
# Processing Record 8 of Set 10 | oliver
# Processing Record 9 of Set 10 | francistown
# Processing Record 10 of Set 10 | rio branco
# Processing Record 11 of Set 10 | poronaysk
# Processing Record 12 of Set 10 | atasu
# Processing Record 13 of Set 10 | jesus de otoro
# Processing Record 14 of Set 10 | bama
# Processing Record 15 of Set 10 | balkanabat
# Processing Record 16 of Set 10 | shingu
# Processing Record 17 of Set 10 | coihaique
# Processing Record 18 of Set 10 | pevek
# Processing Record 19 of Set 10 | coffeyville
# Processing Record 20 of Set 10 | selma
# Processing Record 21 of Set 10 | wattegama
# Processing Record 22 of Set 10 | khandyga
# Processing Record 23 of Set 10 | troitsko-pechorsk
# Processing Record 24 of Set 10 | qaqortoq
# Processing Record 25 of Set 10 | san patricio
# Processing Record 26 of Set 10 | kalemie
# Processing Record 27 of Set 10 | beyneu
# Processing Record 28 of Set 10 | chatellerault
# Processing Record 29 of Set 10 | yenisehir
# Processing Record 30 of Set 10 | podgornoye
# Processing Record 31 of Set 10 | xadani
# City not found. Skipping...
# Processing Record 32 of Set 10 | casian
# Processing Record 33 of Set 10 | cuamba
# Processing Record 34 of Set 10 | amahai
# Processing Record 35 of Set 10 | singapore
# Processing Record 36 of Set 10 | weligama
# Processing Record 37 of Set 10 | aquiraz
# Processing Record 38 of Set 10 | karratha
# Processing Record 39 of Set 10 | karasjok
# Processing Record 40 of Set 10 | sterling
# Processing Record 41 of Set 10 | smithers
# Processing Record 42 of Set 10 | mugumu
# Processing Record 43 of Set 10 | margate
# Processing Record 44 of Set 10 | ust-koksa
# Processing Record 45 of Set 10 | namatanai
# Processing Record 46 of Set 10 | oranjestad
# Processing Record 47 of Set 10 | portland
# Processing Record 48 of Set 10 | culaman
# Processing Record 49 of Set 10 | saint-francois
# Processing Record 0 of Set 11 | soe
# Processing Record 1 of Set 11 | chongwe
# Processing Record 2 of Set 11 | terney
# Processing Record 3 of Set 11 | marsabit
# Processing Record 4 of Set 11 | khash
# Processing Record 5 of Set 11 | vinh long
# Processing Record 6 of Set 11 | puerto del rosario
# Processing Record 7 of Set 11 | calbuco
# Processing Record 8 of Set 11 | vestmannaeyjar
# Processing Record 9 of Set 11 | priladozhskiy
# Processing Record 10 of Set 11 | codrington
# Processing Record 11 of Set 11 | bosaso
# Processing Record 12 of Set 11 | puerto carreno
# Processing Record 13 of Set 11 | makakilo city
# Processing Record 14 of Set 11 | dalbandin
# Processing Record 15 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 16 of Set 11 | challapata
# Processing Record 17 of Set 11 | lobatse
# Processing Record 18 of Set 11 | salinas
# Processing Record 19 of Set 11 | cayenne
# Processing Record 20 of Set 11 | saint-georges
# Processing Record 21 of Set 11 | araouane
# Processing Record 22 of Set 11 | adrar
# Processing Record 23 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 24 of Set 11 | yavaros
# Processing Record 25 of Set 11 | yaan
# Processing Record 26 of Set 11 | taksimo
# Processing Record 27 of Set 11 | shelburne
# Processing Record 28 of Set 11 | libertador general san martin
# Processing Record 29 of Set 11 | batticaloa
# Processing Record 30 of Set 11 | manacapuru
# Processing Record 31 of Set 11 | jimeta
# Processing Record 32 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 33 of Set 11 | medvedovskaya
# Processing Record 34 of Set 11 | prince george
# Processing Record 35 of Set 11 | byron bay
# Processing Record 36 of Set 11 | tagusao
# Processing Record 37 of Set 11 | kashiwazaki
# Processing Record 38 of Set 11 | montepuez
# Processing Record 39 of Set 11 | great falls
# Processing Record 40 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 41 of Set 11 | hirara
# Processing Record 42 of Set 11 | le port
# Processing Record 43 of Set 11 | lawrenceburg
# Processing Record 44 of Set 11 | puerto madryn
# Processing Record 45 of Set 11 | medea
# Processing Record 46 of Set 11 | oxapampa
# Processing Record 47 of Set 11 | kampot
# Processing Record 48 of Set 11 | ternate
# Processing Record 49 of Set 11 | rosarito
# Processing Record 0 of Set 12 | necochea
# Processing Record 1 of Set 12 | ambulu
# Processing Record 2 of Set 12 | ambilobe
# Processing Record 3 of Set 12 | tiarei
# Processing Record 4 of Set 12 | sandpoint
# Processing Record 5 of Set 12 | east hemet
# Processing Record 6 of Set 12 | amazar
# Processing Record 7 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 8 of Set 12 | kindu
# Processing Record 9 of Set 12 | nantucket
# Processing Record 10 of Set 12 | zharkent
# Processing Record 11 of Set 12 | tongchuan
# Processing Record 12 of Set 12 | jamalpur
# Processing Record 13 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 14 of Set 12 | mugur-aksy
# Processing Record 15 of Set 12 | barcelona
# Processing Record 16 of Set 12 | galway
# Processing Record 17 of Set 12 | grand forks
# Processing Record 18 of Set 12 | suzaka
# Processing Record 19 of Set 12 | port keats
# Processing Record 20 of Set 12 | scarborough
# Processing Record 21 of Set 12 | meadow lake
# Processing Record 22 of Set 12 | lalomanu
# City not found. Skipping...
# Processing Record 23 of Set 12 | chifeng
# Processing Record 24 of Set 12 | uruacu
# Processing Record 25 of Set 12 | roma
# Processing Record 26 of Set 12 | bandarbeyla
# Processing Record 27 of Set 12 | mujiayingzi
# Processing Record 28 of Set 12 | armacao dos buzios
# City not found. Skipping...
# Processing Record 29 of Set 12 | itarema
# Processing Record 30 of Set 12 | uklana mandi
# Processing Record 31 of Set 12 | along
# Processing Record 32 of Set 12 | kenora
# Processing Record 33 of Set 12 | tura
# Processing Record 34 of Set 12 | bacolod
# Processing Record 35 of Set 12 | longyearbyen
# Processing Record 36 of Set 12 | severo-kurilsk
# Processing Record 37 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 38 of Set 12 | poum
# Processing Record 39 of Set 12 | emba
# Processing Record 40 of Set 12 | baherden
# Processing Record 41 of Set 12 | sopotnica
# Processing Record 42 of Set 12 | san quintin
# Processing Record 43 of Set 12 | bulungu
# Processing Record 44 of Set 12 | takhtamygda
# Processing Record 45 of Set 12 | vondrozo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          551
# Lat           551
# Lng           551
# Max Temp      551
# Humidity      551
# Cloudiness    551
# Wind Speed    551
# Country       551
# Date          551
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     olive branch  34.9618  -89.8295     60.85        53           0
# 1     punta arenas -53.1500  -70.9167     48.31        76          75
# 2  arraial do cabo -22.9661  -42.0278     71.46        88           0
# 3           atuona  -9.8000 -139.0333     81.52        78          13
# 4           barrow  71.2906 -156.7887     21.22        86         100
#
#    Wind Speed Country        Date
# 0        3.44      US  1683081781
# 1       23.02      CL  1683081674
# 2        0.00      BR  1683081564
# 3       17.87      PF  1683081782
# 4       18.41      US  1683081620

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           olive branch  34.9618  -89.8295     60.85        53           0
# 1           punta arenas -53.1500  -70.9167     48.31        76          75
# 2        arraial do cabo -22.9661  -42.0278     71.46        88           0
# 3                 atuona  -9.8000 -139.0333     81.52        78          13
# 4                 barrow  71.2906 -156.7887     21.22        86         100
#
#          Wind Speed Country        Date
# City_ID
# 0              3.44      US  1683081781
# 1             23.02      CL  1683081674
# 2              0.00      BR  1683081564
# 3             17.87      PF  1683081782
# 4             18.41      US  1683081620

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"],city_data_df["Max Temp"],edgecolors="black",facecolors="skyblue")

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Temperature (2022/10/18)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
#plt.grid(b=True,which="major",axis="both",linestyle="-",color="lightgrey")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"],city_data_df["Humidity"],edgecolors="black",facecolors="skyblue")

#Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.ylim(15,105)
#plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")


# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"],city_data_df["Cloudiness"],edgecolors="black",facecolors="skyblue")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
#plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"],city_data_df["Wind Speed"],edgecolors="black",facecolors="skyblue")

# Incorporate the other graph properties
plt.title("City Latitude Vs. Wind Speed (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
#plt.ylim(0,14)
#plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %%
import datetime

# %%
from datetime import datetime
start_date = datetime(2022,10,18)
end_date = datetime(2022,10,18)

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values,y_values,title,text_coordinates):
    
    #Get regression values
    (slope, intercept, rvalue, pvalue, stderr) = linregress (x_values,y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + " x + " + str(round(intercept,2))
  
    # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq,text_coordinates, fontsize=15, color="red")
    plt.xlabel("Latitude")
    plt.ylabel("Title")
    print(f"The r-squared is: {rvalue}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df= city_data_df.loc[city_data_df["Lat"] >= 0]


# Display sample data
northern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        olive branch  34.9618  -89.8295     60.85        53           0
# 4              barrow  71.2906 -156.7887     21.22        86         100
# 7                hami  42.8000   93.4500     52.92        41          98
# 10       saint george  37.1041 -113.5841     75.79        19           0
# 11           pokrovsk  48.2820   37.1758     44.01        71          16
#
#          Wind Speed Country        Date
# City_ID
# 0              3.44      US  1683081781
# 4             18.41      US  1683081620
# 7             16.62      CN  1683081783
# 10            12.66      US  1683081724
# 11             2.10      UA  1683081784

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1           punta arenas -53.1500  -70.9167     48.31        76          75
# 2        arraial do cabo -22.9661  -42.0278     71.46        88           0
# 3                 atuona  -9.8000 -139.0333     81.52        78          13
# 5            henties bay -22.1160   14.2845     61.09        77          57
# 6         port macquarie -31.4333  152.9167     76.89        38           0
#
#          Wind Speed Country        Date
# City_ID
# 1             23.02      CL  1683081674
# 2              0.00      BR  1683081564
# 3             17.87      PF  1683081782
# 5              3.80     NaN  1683081782
# 6              6.17      AU  1683081783

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']
plot_linear_regression(x_values,y_values, 'Max Temp', (6,30))
# Out:
# The r-squared is: -0.8653153495307222

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
plot_linear_regression(x_values,y_values, 'Max Temp', (-30,40))
# Out:
# The r-squared is: 0.6424922673907201

# %% [markdown]
# **Discussion about the linear relationship**: As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). The southern hemisphere tends to be warmer this time of year than the northern hemisphere

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df ["Lat"]
y_values = northern_hemi_df ["Humidity"]
plot_linear_regression(x_values,y_values, 'Humidity', (40,10))
# Out:
# The r-squared is: 0.05080063031115234

# %%
# Southern Hemisphere
x_values = southern_hemi_df ["Lat"]
y_values = southern_hemi_df ["Humidity"]
plot_linear_regression(x_values,y_values, 'Humidity', (-30,150))
# Out:
# The r-squared is: 0.2350297472092536

# %% [markdown]
# **Discussion about the linear relationship:** There is no strong relationship between latitude and humidity. however there is a slightly larger cluster of northern hemisphere cities with high humidity (above 60% humidity)

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df ["Lat"]
y_values = northern_hemi_df ["Cloudiness"]
plot_linear_regression(x_values,y_values, 'Cloudiness', (40,10))
# Out:
# The r-squared is: 0.0446032198773861

# %%
# Southern Hemisphere
x_values = southern_hemi_df ["Lat"]
y_values = southern_hemi_df ["Cloudiness"]
plot_linear_regression(x_values,y_values, 'Cloudiness', (-30,30))
# Out:
# The r-squared is: 0.18095380125864652

# %% [markdown]
# **Discussion about the linear relationship:** There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities near 0, 80, and 90% cloudiness

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df ["Lat"]
y_values = northern_hemi_df ["Wind Speed"]
plot_linear_regression(x_values,y_values, 'Wind Speed', (40,25))
# Out:
# The r-squared is: 0.18807447595141488

# %%
# Southern Hemisphere
x_values = southern_hemi_df ["Lat"]
y_values = southern_hemi_df ["Wind Speed"]
plot_linear_regression(x_values,y_values, 'Wind Speed', (20, 50))
# Out:
# The r-squared is: -0.25610462054827293

# %% [markdown]
# **Discussion about the linear relationship:** There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind
